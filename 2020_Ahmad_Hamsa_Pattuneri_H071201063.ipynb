# %% [markdown]
# 1. Cari dan unduh dataset dari repository Kaggle dan UCI machine learning. (harus berbeda setiap individu mahasiswa)

# %%
import pandas as pd
data=pd.read_csv("auto_clean.csv")
data
# Out:
#      symboling  normalized-losses         make  ... horsepower-binned diesel gas
# 0            3                122  alfa-romero  ...            Medium      0   1
# 1            3                122  alfa-romero  ...            Medium      0   1
# 2            1                122  alfa-romero  ...            Medium      0   1
# 3            2                164         audi  ...            Medium      0   1
# 4            2                164         audi  ...            Medium      0   1
# ..         ...                ...          ...  ...               ...    ...  ..
# 196         -1                 95        volvo  ...            Medium      0   1
# 197         -1                 95        volvo  ...              High      0   1
# 198         -1                 95        volvo  ...            Medium      0   1
# 199         -1                 95        volvo  ...            Medium      1   0
# 200         -1                 95        volvo  ...            Medium      0   1
#
# [201 rows x 29 columns]

# %% [markdown]
# 2. Ceritakan dataset yang anda ambil dan kira-kira value apa yang anda bisa ambil dari data tersebut.
# Jawab:
#
# Dataset ini mengenai data spesifikasi mobil dari tahun 85.
#
# Kumpulan data ini terdiri dari:
# 1.   spesifikasi mobil dalam hal berbagai karakteristik,
# 2.   peringkat risiko asuransi yang ditetapkan,
# lain.
#
# 1.   kerugian penggunaan yang dinormalisasi dibandingkan dengan mobil

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %% [markdown]
# 3. Visualisasikan dataset yang anda ambil secara sederhana.

# %%
data['make']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 196          volvo
# 197          volvo
# 198          volvo
# 199          volvo
# 200          volvo
# Name: make, Length: 201, dtype: object

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8feedfa090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feedc65d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feed81c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feed40310>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8feecf7990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feecb7050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feec706d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feec23d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8feebe5450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feec1cad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feebdb150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feeb927d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8feeb47e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feeb0a510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feeabfb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8feea81250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8feea388d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8fee9edf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8fee9af610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8fee964c90>]],
#       dtype=object)

# %% [markdown]
# 4. deskripsikan informasi statistik dari data anda secara sederhana

# %%
data.describe()
# Out:
#         symboling  normalized-losses  ...      diesel         gas
# count  201.000000          201.00000  ...  201.000000  201.000000
# mean     0.840796          122.00000  ...    0.099502    0.900498
# std      1.254802           31.99625  ...    0.300083    0.300083
# min     -2.000000           65.00000  ...    0.000000    0.000000
# 25%      0.000000          101.00000  ...    0.000000    1.000000
# 50%      1.000000          122.00000  ...    0.000000    1.000000
# 75%      2.000000          137.00000  ...    0.000000    1.000000
# max      3.000000          256.00000  ...    1.000000    1.000000
#
# [8 rows x 19 columns]
